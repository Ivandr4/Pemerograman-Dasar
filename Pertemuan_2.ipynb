# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivandr4/Pemerograman-Dasar/blob/main/Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Halo, Python! — Praktikum TRPE")

tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)

tegangan = 220
arus = 5.5
aktif = True
nama_alat = "Generator"

print(tegangan, type(tegangan))
print(arus, type(arus))
print(aktif, type(aktif))
print(nama_alat, type(nama_alat))

nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print("Data pertama:", tegangan_harian[0])
print("Data terakhir:", tegangan_harian[-1])

tegangan_harian.append(222.0)

print("Data setelah ditambah:", tegangan_harian)
print("Jumlah data:", len(tegangan_harian))

motor = {
    "nama": "Motor Induksi",
    "daya_kW": 15,
    "tegangan_V": 380,
    "rpm": 1500}

print("Nama motor:", motor["nama"])

motor["rpm"] = 1450

print(motor)

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"},]

print("Nama unit kedua:", pembangkit[1]["nama"])

pembangkit[0]["status"] = "pemeliharaan"

pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 120,
    "status": "operasi"})

print("Data seluruh pembangkit:")
print(pembangkit)
# Out:
# Halo, Python! — Praktikum TRPE
# 18
# 6
# Monocrystalline
# 220 <class 'int'>
# 5.5 <class 'float'>
# True <class 'bool'>
# Generator <class 'str'>
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>
# Data pertama: 217.5
# Data terakhir: 216.9
# Data setelah ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# Jumlah data: 7
# Nama motor: Motor Induksi
# {'nama': 'Motor Induksi', 'daya_kW': 15, 'tegangan_V': 380, 'rpm': 1450}
# Nama unit kedua: Unit-2
# Data seluruh pembangkit:
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
